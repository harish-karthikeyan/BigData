# %% [markdown]
# <a href="https://colab.research.google.com/github/harish-karthikeyan/BigData/blob/main/wordcountprogram.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder \
  .appName("hello") \
  .master("local[*]") \
  .getOrCreate()

# %%
lines = ["hello world", "hello spark", "big data spark"]
sc = spark.sparkContext
rdd = sc.parallelize(lines)
words = rdd.flatMap(lambda line: line.split())
pairs = words.map(lambda word: (word,1))
word_counts = pairs.reduceByKey(lambda a,b: a+b)
print(word_counts.collect())
# Out:
# [('hello', 2), ('world', 1), ('big', 1), ('spark', 2), ('data', 1)]

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://080daba8c71f:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v4.0.3</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>hello</code></dd>
#             </dl>
#         </div>
#
#             </div>
