# %% [markdown]
# <a href="https://colab.research.google.com/github/harish-karthikeyan/BigData/blob/main/WordCount_OnlyWordLength.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder \
  .appName("WordLength") \
  .master("local[*]") \
  .getOrCreate()

# %%
sc = spark.sparkContext
rdd = sc.parallelize(["AI and big data", "Machine learning and deep learning"])
words = rdd.flatMap(lambda line: line.lower().split())
filtered = words.filter(lambda word: len(word) > 3)
pairs = filtered.map(lambda word:(word ,1))
counts = pairs.reduceByKey(lambda a,b : a+b)
print(counts.collect())
# Out:
# [('machine', 1), ('learning', 2), ('data', 1), ('deep', 1)]
